# %%
import random
number = [3,6,5,4,7,2,1,0]
# random.shuffle(number)
print("Part one: \n",number) # Find the first pair  that the right is greate than left
switch_point =-1
for idx in range(len(number)-1):
    i=len(number)-1-idx
    left_num=number[i-1]
    right_num=number[i]
    print(idx,left_num,right_num)
    if(left_num<right_num):
        switch_point=i
        break
if(switch_point==-1):
    print("FINISH")
print("switch point idx:",switch_point-1,"number:",number[switch_point-1])
# Out:
# Part one:
#  [3, 6, 5, 4, 7, 2, 1, 0]
# 0 1 0
# 1 2 1
# 2 7 2
# 3 4 7
# switch point idx: 3 number: 4

# %%
print("==================")
switch_num=len(number)+1
switch_index =-1
switch_point_idx=switch_point-1
print("all switch candidate",number[switch_point:])

for ele in number[switch_point:]:
    switch_point_idx+=1
    if(ele>number[switch_point-1]): #Great than 4
        # print("grt 4:",ele)
        if(ele<switch_num): #smallest number in candidates
            switch_num = ele
            switch_index = switch_point_idx
            # print("switch number is:",switch_num)
            # print("swich_number is:",number[switch_point_idx],switch_point_idx)
print("switch number is:",switch_num,"index is ",switch_index)
number[switch_point-1],number[switch_index] =number[switch_index],number[switch_point-1]
print("switch the number at switch point:",number)
# Out:
# ...
# all switch candidate [7, 2, 1, 0]
# switch number is: 7 index is  4
# switch the number at switch point: [3, 6, 5, 7, 4, 2, 1, 0]

# %%
print("==================")
number_reversed=number[switch_point:]
for idx,ele in enumerate( reversed(number_reversed)):
    number[switch_point+idx]=ele
print("result is",number)
# Out:
# ...
# result is [3, 6, 5, 7, 0, 1, 2, 4]

# %%
# Find the first pair  that the right is greate than left
import random
input_list=[1,2,3,4,5,6,0,7]
# random.shuffle(input_list)
print("input\t",input_list)
return_list=input_list
switch_point =-1
pair_order_bound=len(input_list)-1
for idx in range(pair_order_bound):
    i=pair_order_bound-idx
    left_num=input_list[i-1]
    right_num=input_list[i]
    if(left_num<right_num):
        switch_point=i
        break
if(switch_point==-1):
    print("finish")
else:
    switch_num=len(input_list)+1
    #Part two
    switch_index =-1
    switch_point_idx=switch_point-1
    for ele in input_list[switch_point:]:
        switch_point_idx+=1
        if(ele>input_list[switch_point-1]):
            if(ele<switch_num): #smallest input_list in candidates
                switch_num = ele
                switch_index = switch_point_idx
    return_list[switch_point-1],input_list[switch_index] =input_list[switch_index],input_list[switch_point-1]
    print("switch\t",return_list)
    number_reversed=input_list[switch_point:]
    #part three
    for idx,ele in enumerate( reversed(number_reversed)):
        return_list[switch_point+idx]=ele
    print("final\t",return_list)
# Out:
# input	 [1, 2, 3, 4, 5, 6, 0, 7]
# switch	 [1, 2, 3, 4, 5, 6, 7, 0]
# final	 [1, 2, 3, 4, 5, 6, 7, 0]

# %%
# Find the first pair  that the right is greate than left
input_list=[0,1,2,3,4,5,6,7]
print("input\t",input_list)
    
with open ("anwer.txt","w") as f:
    for test_cnt in range(40320):
        print("input\t",input_list)
        return_list=input_list
        switch_point =-1
        pair_order_bound=len(input_list)-1
        for idx in range(pair_order_bound):
            i=pair_order_bound-idx
            left_num=input_list[i-1]
            right_num=input_list[i]
            if(left_num<right_num):
                switch_point=i
                break
        if(switch_point==-1):
            print("finish")
        else:
            switch_num=len(input_list)+1
            #Part two
            switch_index =-1
            switch_point_idx=switch_point-1
            for ele in input_list[switch_point:]:
                switch_point_idx+=1
                if(ele>input_list[switch_point-1]):
                    if(ele<switch_num): #smallest input_list in candidates
                        switch_num = ele
                        switch_index = switch_point_idx
            return_list[switch_point-1],input_list[switch_index] =input_list[switch_index],input_list[switch_point-1]
            # print("switch\t",return_list)
            number_reversed=input_list[switch_point:]
            #part three
            for idx,ele in enumerate( reversed(number_reversed)):
                return_list[switch_point+idx]=ele
            # print("final\t",return_list)
            input_list=return_list
            for ans_ele in input_list:
                f.write(str(ans_ele)+" ")
            f.write("\n")
# Out:
# input	 [0, 1, 2, 3, 4, 5, 6, 7]
# input	 [0, 1, 2, 3, 4, 5, 6, 7]
# input	 [0, 1, 2, 3, 4, 5, 7, 6]
# input	 [0, 1, 2, 3, 4, 6, 5, 7]
# input	 [0, 1, 2, 3, 4, 6, 7, 5]
# input	 [0, 1, 2, 3, 4, 7, 5, 6]
# input	 [0, 1, 2, 3, 4, 7, 6, 5]
# input	 [0, 1, 2, 3, 5, 4, 6, 7]
# input	 [0, 1, 2, 3, 5, 4, 7, 6]
# input	 [0, 1, 2, 3, 5, 6, 4, 7]
# input	 [0, 1, 2, 3, 5, 6, 7, 4]
# input	 [0, 1, 2, 3, 5, 7, 4, 6]
# input	 [0, 1, 2, 3, 5, 7, 6, 4]
# input	 [0, 1, 2, 3, 6, 4, 5, 7]
# input	 [0, 1, 2, 3, 6, 4, 7, 5]
# input	 [0, 1, 2, 3, 6, 5, 4, 7]
# input	 [0, 1, 2, 3, 6, 5, 7, 4]
# input	 [0, 1, 2, 3, 6, 7, 4, 5]
# input	 [0, 1, 2, 3, 6, 7, 5, 4]
# input	 [0, 1, 2, 3, 7, 4, 5, 6]
# input	 [0, 1, 2, 3, 7, 4, 6, 5]
# input	 [0, 1, 2, 3, 7, 5, 4, 6]
# input	 [0, 1, 2, 3, 7, 5, 6, 4]
# input	 [0, 1, 2, 3, 7, 6, 4, 5]
# input	 [0, 1, 2, 3, 7, 6, 5, 4]
# input	 [0, 1, 2, 4, 3, 5, 6, 7]
# input	 [0, 1, 2, 4, 3, 5, 7, 6]
# input	 [0, 1, 2, 4, 3, 6, 5, 7]
# input	 [0, 1, 2, 4, 3, 6, 7, 5]
# ...

# %%
def all_list_algorithm(input_list):
    # Find the first pair  that the right is greate than left
    return_list=input_list
    switch_point =-1
    pair_order_bound=len(input_list)-1
    for idx in range(pair_order_bound):
        i=pair_order_bound-idx
        left_num=input_list[i-1]
        right_num=input_list[i]
        if(left_num<right_num):
            switch_point=i
            break
    if(switch_point==-1):
        return("finish")
    else:
        switch_num=len(input_list)+1
        #Part two
        switch_index =-1
        switch_point_idx=switch_point-1
        for ele in input_list[switch_point:]:
            switch_point_idx+=1
            if(ele>input_list[switch_point-1]):
                if(ele<switch_num): #smallest input_list in candidates
                    switch_num = ele
                    switch_index = switch_point_idx
        return_list[switch_point-1],input_list[switch_index] =input_list[switch_index],input_list[switch_point-1]
        number_reversed=input_list[switch_point:]
        #part three
        for idx,ele in enumerate( reversed(number_reversed)):
            return_list[switch_point+idx]=ele
        return (return_list)

# %%
def all_list_algorithm_iter(input_list):
    # Find the first pair  that the right is greate than left
    print("input:\t",input_list)
    return_list=input_list
    switch_point =-1
    pair_order_bound=len(input_list)-1
    for idx in range(pair_order_bound):
        i=pair_order_bound-idx
        left_num=input_list[i-1]
        right_num=input_list[i]
        if(left_num<right_num):
            switch_point=i
            break
    if(switch_point==-1):
        yield(None)
    else:
        switch_num=len(input_list)+1
        #Part two
        switch_index =-1
        switch_point_idx=switch_point-1
        for ele in input_list[switch_point:]:
            switch_point_idx+=1
            if(ele>input_list[switch_point-1]):
                if(ele<switch_num): #smallest input_list in candidates
                    switch_num = ele
                    switch_index = switch_point_idx
        return_list[switch_point-1],input_list[switch_index] =input_list[switch_index],input_list[switch_point-1]
        print("sw:\t",return_list)
        number_reversed=input_list[switch_point:]
        #part three
        for idx,ele in enumerate( reversed(number_reversed)):
            return_list[switch_point+idx]=ele
        print("end\t",return_list)
        yield (return_list)

# %%
#Check Golden Answer
    
from itertools import permutations
number=[0,1,2,3,4,5,6,7]
possible=list(permutations(range(len(number))))
out_come=[]
out_come.append(number)
# for i in range(len(possible)):
for i in range(10):
    print(i)
    number=next(all_list_algorithm_iter(number))
    out_come.append(number)
# print(len(out_come))
# print(len(possible))
# out_come
# Out:
# 0
# input:	 [7, 6, 5, 4, 3, 2, 1, 0]
# 1
# input:	 None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-cfadd06424a3> in <module>
#       8 for i in range(10):
#       9     print(i)
# ---> 10     number=next(all_list_algorithm_iter(number))
#      11     out_come.append(number)
#      12 # print(len(out_come))
#
# <ipython-input-6-f801ca560b84> in all_list_algorithm_iter(input_list)
#       4     return_list=input_list
#       5     switch_point =-1
# ----> 6     pair_order_bound=len(input_list)-1
#       7     for idx in range(pair_order_bound):
#       8         i=pair_order_bound-idx
#
# TypeError: object of type 'NoneType' has no len()

# %%
last_value =None
def all_list_algorithm(input_list):
    # Find the first pair  that the right is greate than left
    return_list=input_list
    switch_point =-1
    pair_order_bound=len(input_list)-1
    for idx in range(pair_order_bound):
        i=pair_order_bound-idx
        left_num=input_list[i-1]
        right_num=input_list[i]
        if(left_num<right_num):
            switch_point=i
            break
    if(switch_point==-1):
        return("finish!")
    else:
        switch_num=len(input_list)+1
        #Part two
        switch_index =-1
        switch_point_idx=switch_point-1
        for ele in input_list[switch_point:]:
            switch_point_idx+=1
            if(ele>input_list[switch_point-1]):
                if(ele<switch_num): #smallest input_list in candidates
                    switch_num = ele
                    switch_index = switch_point_idx
        return_list[switch_point-1],input_list[switch_index] =input_list[switch_index],input_list[switch_point-1]
        number_reversed=input_list[switch_point:]
        #part three
        for idx,ele in enumerate( reversed(number_reversed)):
            return_list[switch_point+idx]=ele
        yield (return_list)

# %%
# Read list and output work/ job 
# W/J 3 bit
def cost_fun(number_list):
    cost_table=[[11,25,53,41,59,32,25,59],
                [4,11,25,11,59,31,53,11],
                [11,59,15,11,15,15,53,53],
                [4,59,32,34,53,41,34,59],
                [15,32,41,34,4,59,34,32],
                [41,59,59,4,4,41,34,34],
                [53,31,25,41,59,32,31,53],
                [11,31,25,11,34,34,56,32]]
    return_list=list([cost_table[0][number_list[0]],
                     cost_table[1][number_list[1]],
                     cost_table[2][number_list[2]],
                     cost_table[3][number_list[3]],
                     cost_table[4][number_list[4]],
                     cost_table[5][number_list[5]],
                     cost_table[6][number_list[6]],
                     cost_table[7][number_list[7]]])
    return(return_list)
cost_fun([0,1,2,3,4,5,6,7])
# Out:
# [11, 11, 15, 34, 4, 41, 31, 32]

# %%
#sum of cost 
cost_min =999
cost_order_possible=[]
all_possible=[]
number=[0,1,2,3,4,5,6,7]
possible=list(permutations(range(len(number))))
for i in range(len(possible)):
    #find min cost 
    if(cost_per_once<cost_min):
        cost_min=cost_per_once
        cost_order_possible=[]
        cost_order_possible.append(number)
        # print(number)
    elif(cost_per_once==cost_min):
        cost_order_possible.append(number)
        # print(number)
    else:
        pass
    cost_per_once=sum(cost_fun(number))
    # number=all_list_algorithm(number)
    next(number for number in all_list_algorithm(number) )
    # print(number)
print("cost:",cost_min)
print("order:",cost_order_possible)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-117-45d548c7e971> in <module>
#      19     cost_per_once=sum(cost_fun(number))
#      20     # number=all_list_algorithm(number)
# ---> 21     next(number for number in all_list_algorithm(number) )
#      22     # print(number)
#      23 print("cost:",cost_min)
#
# StopIteration:

# %%
import numpy as np 
compare_list =np.array([7,17,27,39])
for num in compare_list:
    bin_format = np.binary_repr(num,6)
    print("idx",int(bin_format[0:3],2),"value",int(bin_format[3:],2))
# Out:
# idx 0 value 7
# idx 2 value 1
# idx 3 value 3
# idx 4 value 7
